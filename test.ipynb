# %%
from dotenv import load_dotenv
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# Load environment variables
load_dotenv()

# Initialize chat model with 40-mini
chat = ChatOpenAI(
    model_name="gpt-4o-mini",
    streaming=True,
    callbacks=[StreamingStdOutCallbackHandler()],
    temperature=0
)

# Generate response
response = chat([HumanMessage(content="Write me a song about sparkling water.")])
print(response)
# Out:
# **Verse 1**
# In a glass, it starts to dance,
# Tiny bubbles, a fizzy romance,
# Crystal clear, like a summer sky,
# With every sip, I feel so high.
#
# **Chorus**
# Sparkling water, you’re my delight,
# Bubbling joy, you shine so bright,
# With a twist of lime or a hint of mint,
# Every drop’s a celebration, every sip’s a hint.
#
# **Verse 2**
# On a hot day, you’re my cool embrace,
# Effervescent magic, you set the pace,
# From the mountains, you flow so free,
# A sparkling treasure, just for me.
#
# **Chorus**
# Sparkling water, you’re my delight,
# Bubbling joy, you shine so bright,
# With a twist of lime or a hint of mint,
# Every drop’s a celebration, every sip’s a hint.
#
# **Bridge**
# In the quiet moments, or a lively crowd,
# You’re the life of the party, you make me proud,
# No sugar needed, just pure and true,
# Sparkling water, I’m in love with you.
#
# **Chorus**
# Sparkling water, you’re my delight,
# Bubbling joy, you shine so bright,
# With a twist of lime or a hint of mint,
# Every drop’s a celebration, every sip’s a hint.
#
# **Outro**
# So here’s to the bubbles, the sparkle, the cheer,
# With every refreshing sip, I hold you near,
# Sparkling water, forever you’ll be,
# The fizzy little joy that sets my heart free.  content='**Verse 1**  \nIn a glass, it starts to dance,  \nTiny bubbles, a fizzy romance,  \nCrystal clear, like a summer sky,  \nWith every sip, I feel so high.  \n\n**Chorus**  \nSparkling water, you’re my delight,  \nBubbling joy, you shine so bright,  \nWith a twist of lime or a hint of mint,  \nEvery drop’s a celebration, every sip’s a hint.  \n\n**Verse 2**  \nOn a hot day, you’re my cool embrace,  \nEffervescent magic, you set the pace,  \nFrom the mountains, you flow so free,  \nA sparkling treasure, just for me.  \n\n**Chorus**  \nSparkling water, you’re my delight,  \nBubbling joy, you shine so bright,  \nWith a twist of lime or a hint of mint,  \nEvery drop’s a celebration, every sip’s a hint.  \n\n**Bridge**  \nIn the quiet moments, or a lively crowd,  \nYou’re the life of the party, you make me proud,  \nNo sugar needed, just pure and true,  \nSparkling water, I’m in love with you.  \n\n**Chorus**  \nSparkling water, you’re my delight,  \nBubbling joy, you shine so bright,  \nWith a twist of lime or a hint of mint,  \nEvery drop’s a celebration, every sip’s a hint.  \n\n**Outro**  \nSo here’s to the bubbles, the sparkle, the cheer,  \nWith every refreshing sip, I hold you near,  \nSparkling water, forever you’ll be,  \nThe fizzy little joy that sets my heart free.  ' additional_kwargs={} response_metadata={'finish_reason': 'stop'} id='run-dfd8b377-00ba-46af-9fab-fff3f9b77e25-0'
